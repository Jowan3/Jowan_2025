# %% [raw]
# ---
# layout: post
# title: Final
# description: tri 2 final review
# permalink: /summary/
# course: { csp:{week:1}  }
# comments: true
# sticky_rank: 1
# ---

# %% [markdown]
# The purpose of our group creating a chess game website "Pwansy" is to provide an engaging platform for players to compete, track their progress, and enhance their skills through interactive features.
#
# **Purpose of the project**
# - Created a chess game website to promote competitive play and provide players with real-time leaderboards and game tracking.
#
# **indivisual feature**
#
# frontend design
#
# - created a leaderboard component to display top players and their scores.
# - Designed a runner-up table to highlight additional competitors.
#
# Database Integration:
#
# - Set up a database to store player stats, game results, and ranking data.
# - Implemented methods to retrieve, update, and back up the database.
#
# Big Idea 1.4 Debugging Code and Fixing Errors: Fixed backend for various schema issues through iterations
# Big Idea 2 Data: Utilized pgn CRUD api in new ways in coordination with user API to make manager tab login based and incorporate it in overall system with aarush's analysis page
#
# **API**
#
# Defined methods for CRUD operations:
# GET for retrieving player rankings.
# POST for adding new players or game results.
# PUT for updating scores or ranks.
# DELETE for removing inactive players.
# Class Methods:
#
# - Wrote methods for sequencing (fetching and sorting scores), selection (filtering top players), and iteration (looping through player data).
#
# **input/ output group**
#
# Frontend Input/Output:
#
# Integrated a playable chessboard for users to play games.
# Created an input form for players to submit scores or join the game.
# Displayed API responses dynamically in the leaderboard and runners-up table.
#
# Tested all API endpoints using Postman to ensure they return correct RESTful responses.
# Demonstrated error handling with status codes (e.g., 200 for success, 404 for errors).
#
# ### 6. Jowan Elzein 5-point Burndown
# - Developed Chess Wiki Resource Hub – Designed and implemented a structured resource table with curated chess tips, strategy guides, and opening principles. Integrated external links for easy access to learning materials.
# - Created Interactive Chat System – Built a user-submitted recommendations section with a chatbox, allowing users to post and discuss chess tips. Implemented backend API integration for storing, retrieving, and moderating user messages.
# - Designed Thematic User Interface – Styled the page using SASS principles, applying a dark mode theme with hover effects, structured layouts, and a background image for an immersive experience
# - Integrated User API & Role-Based Access – Enabled API calls to retrieve user roles, allowing admins to update and delete messages, ensuring content moderation and interactive discussions
# - Optimized UX and Navigation – Improved overall page organization, ensuring consistency with the team’s design system. Identified and resolved navigation issues to enhance user experience
#
# ##MCQ
#
# Total Score: 40/67
# improvement from last times: 19/66
#
# Mistakes: Overall, I noticed I had difficulty with the arithmetic ascpet of CSP, including things like bits and binary code. (Q11, Q12, Q49,). I also had some difficulty understanding larger flowcharts or code chunks (Q23, Q35, Q39, Q67). When the diagrams are really long with multiple parts, it takes longer for me to process and I end up getting the question incorrect.
#
# ##Night at the Museum
#
# Positives:
#
# The website was fun, clean, and well-designed.
# Users appreciated the Stockfish chess engine integration and found the experience simple and easy to use.
# Many liked the chess analyzer, highlighting its ability to review moves, provide ratings, and analyze games.
# Features like move recording, leaderboard, and ELO selection were well received.
# The ability to download a PNG file for move analysis was a cool addition.
# The requirement to lose before accessing a feature was an interesting touch.
# The project was seen as impressive, functional, and helpful for improving chess skills.
# Constructive Feedback:
#
# Some users wanted better CSS styling and a more consistent theme.
# The UI had some bugs, and the ELO selection could be more elegant.
# Suggestions to add an edit feature for chess moves and possibly a rating system for move accuracy.
#
# <p align="center">
#   <img src="https://media.discordapp.net/attachments/1248848112492220509/1344888630778527794/image.jpg?ex=67cbc724&is=67ca75a4&hm=97f41f27848799ea5ebe5ea7284d676b9dd0f2bc6e96796f02ae698e3c942488&=&format=webp&width=606&height=1312" width="24%">
#   <img src="https://cdn.discordapp.com/attachments/1248848112492220509/1344889426282680370/image.jpg?ex=67cbc7e2&is=67ca7662&hm=2d047d8c3b5a8f874f17bcc5614bd32afda7f8bac2c0488425466e9d4002c2e1&" width="24%">
#   <img src="https://media.discordapp.net/attachments/1248848112492220509/1344888631671652412/image.jpg?ex=67cbc724&is=67ca75a4&hm=c9254f2d3664f57653fe3838786eff5d1e8c276a5633a90554dd2e1496cecd34&=&format=webp&width=606&height=1312" width="24%">
#   <img src="https://media.discordapp.net/attachments/1248848112492220509/1344889264491597875/image.jpg?ex=67cbc7bb&is=67ca763b&hm=a76ccd1817f021fe3b000be854d83634001478cd7492437e2051b16f64482797&=&format=webp&width=1140&height=1520" width="24%">
# </p>
#
# ##Thoughts and reflection
#
#  Over all I struggled with this Trimester a lot with missing the first week it was hard to catch us as well as work with a team, it was stressfull and I was faling behind a lot more once the API stuff got introduced. My weakness of not knowing the fundementals of a computer were really starting to show.
#
#  i overall think that i deserve a 8.4/10 becasue despite all the challenges i faced with changing my feature from the leaderboard to the now tips wiki page, i was able to overcome and as my teamates for help as well as other students from your ither cs classes.
